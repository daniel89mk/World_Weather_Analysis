# %% [markdown]
# # Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
cities =[]

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 773

# %%
import requests

from datetime import datetime
from config import weather_api_key

# %%
print(weather_api_key)
# Out:
# be1d779d7e46348b69e513261154e620

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be1d779d7e46348b69e513261154e620

# %%
city_data =[]

print("Beginning Data Retrieval")
print("----------------------------")

# Create counters.
record_count = 1
set_count = 1


for index, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | ponta do sol
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | kloulklubed
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | dikson
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | bubaque
# Processing Record 10 of Set 1 | caravelas
# Processing Record 11 of Set 1 | winnemucca
# Processing Record 12 of Set 1 | ambilobe
# Processing Record 13 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | port hedland
# Processing Record 16 of Set 1 | nyandoma
# Processing Record 17 of Set 1 | kovdor
# Processing Record 18 of Set 1 | orsha
# Processing Record 19 of Set 1 | krasnokamensk
# Processing Record 20 of Set 1 | mana
# Processing Record 21 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 1 | nouadhibou
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | mangrol
# Processing Record 28 of Set 1 | salalah
# Processing Record 29 of Set 1 | nouakchott
# Processing Record 30 of Set 1 | hilo
# Processing Record 31 of Set 1 | kodiak
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | bathsheba
# Processing Record 34 of Set 1 | ribeira grande
# Processing Record 35 of Set 1 | fairbanks
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | upernavik
# Processing Record 38 of Set 1 | saint-philippe
# Processing Record 39 of Set 1 | kisangani
# Processing Record 40 of Set 1 | kushima
# Processing Record 41 of Set 1 | torbay
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | cherskiy
# Processing Record 44 of Set 1 | nishihara
# Processing Record 45 of Set 1 | punta de piedra
# Processing Record 46 of Set 1 | victoria
# Processing Record 47 of Set 1 | yenagoa
# Processing Record 48 of Set 1 | faanui
# Processing Record 49 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 1 | bandarbeyla
# Processing Record 1 of Set 2 | dingle
# Processing Record 2 of Set 2 | bulgan
# Processing Record 3 of Set 2 | kargasok
# Processing Record 4 of Set 2 | adelaide
# Processing Record 5 of Set 2 | san patricio
# Processing Record 6 of Set 2 | abalak
# Processing Record 7 of Set 2 | khipro
# Processing Record 8 of Set 2 | longyearbyen
# Processing Record 9 of Set 2 | cidreira
# Processing Record 10 of Set 2 | puerto ayora
# Processing Record 11 of Set 2 | pontiac
# Processing Record 12 of Set 2 | acapulco
# Processing Record 13 of Set 2 | aklavik
# Processing Record 14 of Set 2 | san quintin
# Processing Record 15 of Set 2 | salinas
# Processing Record 16 of Set 2 | kaitangata
# Processing Record 17 of Set 2 | cape town
# Processing Record 18 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 2 | komsomolskiy
# Processing Record 20 of Set 2 | svetlyy
# Processing Record 21 of Set 2 | thompson
# Processing Record 22 of Set 2 | nikolskoye
# Processing Record 23 of Set 2 | hay river
# Processing Record 24 of Set 2 | mataura
# Processing Record 25 of Set 2 | ushuaia
# Processing Record 26 of Set 2 | talcahuano
# Processing Record 27 of Set 2 | klaksvik
# Processing Record 28 of Set 2 | hermanus
# Processing Record 29 of Set 2 | norman wells
# Processing Record 30 of Set 2 | saryshagan
# City not found. Skipping...
# Processing Record 31 of Set 2 | namibe
# Processing Record 32 of Set 2 | lebu
# Processing Record 33 of Set 2 | krasnoselkup
# Processing Record 34 of Set 2 | barrow
# Processing Record 35 of Set 2 | swan hill
# Processing Record 36 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 2 | hobart
# Processing Record 38 of Set 2 | mergui
# City not found. Skipping...
# Processing Record 39 of Set 2 | sebinkarahisar
# Processing Record 40 of Set 2 | castro
# Processing Record 41 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 42 of Set 2 | brigantine
# Processing Record 43 of Set 2 | tarakan
# Processing Record 44 of Set 2 | tuktoyaktuk
# Processing Record 45 of Set 2 | vardo
# Processing Record 46 of Set 2 | jamestown
# Processing Record 47 of Set 2 | ust-nera
# Processing Record 48 of Set 2 | pacifica
# Processing Record 49 of Set 2 | dire dawa
# Processing Record 50 of Set 2 | allapalli
# Processing Record 1 of Set 3 | avarua
# Processing Record 2 of Set 3 | te anau
# Processing Record 3 of Set 3 | ilulissat
# Processing Record 4 of Set 3 | mar del plata
# Processing Record 5 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 6 of Set 3 | uzhur
# Processing Record 7 of Set 3 | butaritari
# Processing Record 8 of Set 3 | kurilsk
# Processing Record 9 of Set 3 | provideniya
# Processing Record 10 of Set 3 | gat
# Processing Record 11 of Set 3 | holoby
# Processing Record 12 of Set 3 | husavik
# Processing Record 13 of Set 3 | general roca
# Processing Record 14 of Set 3 | gubkinskiy
# Processing Record 15 of Set 3 | yellowknife
# Processing Record 16 of Set 3 | zhangjiakou
# Processing Record 17 of Set 3 | arraial do cabo
# Processing Record 18 of Set 3 | tura
# Processing Record 19 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 3 | luderitz
# Processing Record 21 of Set 3 | portpatrick
# City not found. Skipping...
# Processing Record 22 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 3 | port-gentil
# Processing Record 24 of Set 3 | sindang
# Processing Record 25 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 3 | pangai
# Processing Record 27 of Set 3 | vikindu
# Processing Record 28 of Set 3 | seymchan
# Processing Record 29 of Set 3 | sungaipenuh
# Processing Record 30 of Set 3 | kahului
# Processing Record 31 of Set 3 | aguimes
# Processing Record 32 of Set 3 | arlit
# Processing Record 33 of Set 3 | senneterre
# Processing Record 34 of Set 3 | alice springs
# Processing Record 35 of Set 3 | hershey
# Processing Record 36 of Set 3 | nalut
# Processing Record 37 of Set 3 | lere
# Processing Record 38 of Set 3 | misratah
# Processing Record 39 of Set 3 | merauke
# Processing Record 40 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 3 | itarema
# Processing Record 42 of Set 3 | kachiry
# Processing Record 43 of Set 3 | nantucket
# Processing Record 44 of Set 3 | fjerritslev
# Processing Record 45 of Set 3 | bengkulu
# Processing Record 46 of Set 3 | guebwiller
# Processing Record 47 of Set 3 | saint anthony
# Processing Record 48 of Set 3 | katsuura
# Processing Record 49 of Set 3 | east london
# Processing Record 50 of Set 3 | manbij
# Processing Record 1 of Set 4 | porto belo
# Processing Record 2 of Set 4 | rajpur
# Processing Record 3 of Set 4 | hithadhoo
# Processing Record 4 of Set 4 | manicore
# Processing Record 5 of Set 4 | nanortalik
# Processing Record 6 of Set 4 | tessalit
# Processing Record 7 of Set 4 | dongsheng
# Processing Record 8 of Set 4 | vostochnyy
# Processing Record 9 of Set 4 | loei
# Processing Record 10 of Set 4 | aswan
# Processing Record 11 of Set 4 | vanimo
# Processing Record 12 of Set 4 | tobol
# Processing Record 13 of Set 4 | bababe
# City not found. Skipping...
# Processing Record 14 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 4 | touros
# Processing Record 16 of Set 4 | tokmak
# Processing Record 17 of Set 4 | huarmey
# Processing Record 18 of Set 4 | prince rupert
# Processing Record 19 of Set 4 | severobaykalsk
# Processing Record 20 of Set 4 | kieta
# Processing Record 21 of Set 4 | kruisfontein
# Processing Record 22 of Set 4 | kabo
# Processing Record 23 of Set 4 | grindavik
# Processing Record 24 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 4 | georgetown
# Processing Record 26 of Set 4 | kjollefjord
# Processing Record 27 of Set 4 | ruiz
# Processing Record 28 of Set 4 | vuktyl
# Processing Record 29 of Set 4 | hobyo
# Processing Record 30 of Set 4 | port macquarie
# Processing Record 31 of Set 4 | cabo san lucas
# Processing Record 32 of Set 4 | parabel
# Processing Record 33 of Set 4 | moree
# Processing Record 34 of Set 4 | kalmunai
# Processing Record 35 of Set 4 | khatanga
# Processing Record 36 of Set 4 | pokhara
# Processing Record 37 of Set 4 | guaymas
# Processing Record 38 of Set 4 | saskylakh
# Processing Record 39 of Set 4 | saint-pierre
# Processing Record 40 of Set 4 | chapais
# Processing Record 41 of Set 4 | sergeyevka
# Processing Record 42 of Set 4 | elban
# Processing Record 43 of Set 4 | tiruvottiyur
# City not found. Skipping...
# Processing Record 44 of Set 4 | teknaf
# Processing Record 45 of Set 4 | westport
# Processing Record 46 of Set 4 | mezen
# Processing Record 47 of Set 4 | darnah
# Processing Record 48 of Set 4 | thinadhoo
# Processing Record 49 of Set 4 | urumqi
# Processing Record 50 of Set 4 | palmares
# Processing Record 1 of Set 5 | sabzevar
# Processing Record 2 of Set 5 | takhtamygda
# Processing Record 3 of Set 5 | sitka
# Processing Record 4 of Set 5 | puerto carreno
# Processing Record 5 of Set 5 | shaowu
# Processing Record 6 of Set 5 | chuy
# Processing Record 7 of Set 5 | basco
# Processing Record 8 of Set 5 | sola
# Processing Record 9 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 5 | saldanha
# Processing Record 11 of Set 5 | fare
# Processing Record 12 of Set 5 | atar
# Processing Record 13 of Set 5 | bambous virieux
# Processing Record 14 of Set 5 | portobelo
# Processing Record 15 of Set 5 | manaure
# Processing Record 16 of Set 5 | flinders
# Processing Record 17 of Set 5 | beyneu
# Processing Record 18 of Set 5 | sao filipe
# Processing Record 19 of Set 5 | aracoiaba
# Processing Record 20 of Set 5 | nanaimo
# Processing Record 21 of Set 5 | the valley
# Processing Record 22 of Set 5 | port elizabeth
# Processing Record 23 of Set 5 | fortuna
# Processing Record 24 of Set 5 | malanje
# Processing Record 25 of Set 5 | mokrousovo
# Processing Record 26 of Set 5 | kitaibaraki
# Processing Record 27 of Set 5 | cabedelo
# Processing Record 28 of Set 5 | bitung
# Processing Record 29 of Set 5 | kathu
# Processing Record 30 of Set 5 | grand-lahou
# Processing Record 31 of Set 5 | glebychevo
# Processing Record 32 of Set 5 | visby
# Processing Record 33 of Set 5 | riyadh
# Processing Record 34 of Set 5 | batemans bay
# Processing Record 35 of Set 5 | esperance
# Processing Record 36 of Set 5 | zeya
# Processing Record 37 of Set 5 | saint-augustin
# Processing Record 38 of Set 5 | lavrentiya
# Processing Record 39 of Set 5 | mahebourg
# Processing Record 40 of Set 5 | miranorte
# City not found. Skipping...
# Processing Record 41 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 5 | severo-kurilsk
# Processing Record 43 of Set 5 | sangar
# Processing Record 44 of Set 5 | broken hill
# Processing Record 45 of Set 5 | stephenville
# Processing Record 46 of Set 5 | kavieng
# Processing Record 47 of Set 5 | asayita
# City not found. Skipping...
# Processing Record 48 of Set 5 | porbandar
# Processing Record 49 of Set 5 | yerbogachen
# Processing Record 50 of Set 5 | gizo
# Processing Record 1 of Set 6 | kutum
# Processing Record 2 of Set 6 | roma
# Processing Record 3 of Set 6 | powell river
# Processing Record 4 of Set 6 | san cristobal
# Processing Record 5 of Set 6 | suntar
# Processing Record 6 of Set 6 | skovde
# City not found. Skipping...
# Processing Record 7 of Set 6 | miramar
# Processing Record 8 of Set 6 | mattru
# Processing Record 9 of Set 6 | ertil
# Processing Record 10 of Set 6 | bunia
# Processing Record 11 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 12 of Set 6 | chokurdakh
# Processing Record 13 of Set 6 | hervey bay
# Processing Record 14 of Set 6 | tchollire
# Processing Record 15 of Set 6 | bolshiye uki
# City not found. Skipping...
# Processing Record 16 of Set 6 | saint george
# Processing Record 17 of Set 6 | los llanos de aridane
# Processing Record 18 of Set 6 | coihaique
# Processing Record 19 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 6 | marzuq
# Processing Record 21 of Set 6 | pochutla
# Processing Record 22 of Set 6 | olafsvik
# Processing Record 23 of Set 6 | guatire
# Processing Record 24 of Set 6 | shelburne
# Processing Record 25 of Set 6 | carutapera
# Processing Record 26 of Set 6 | constitucion
# Processing Record 27 of Set 6 | hualmay
# Processing Record 28 of Set 6 | unguia
# Processing Record 29 of Set 6 | limenaria
# Processing Record 30 of Set 6 | romitan
# Processing Record 31 of Set 6 | aljezur
# Processing Record 32 of Set 6 | yola
# Processing Record 33 of Set 6 | palmer
# Processing Record 34 of Set 6 | canto do buriti
# Processing Record 35 of Set 6 | puerto madryn
# Processing Record 36 of Set 6 | necochea
# Processing Record 37 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 38 of Set 6 | samarai
# Processing Record 39 of Set 6 | buala
# Processing Record 40 of Set 6 | dolores
# Processing Record 41 of Set 6 | tyler
# Processing Record 42 of Set 6 | praia
# Processing Record 43 of Set 6 | imbituba
# Processing Record 44 of Set 6 | sabang
# Processing Record 45 of Set 6 | celestun
# Processing Record 46 of Set 6 | bredasdorp
# Processing Record 47 of Set 6 | hasaki
# Processing Record 48 of Set 6 | boa vista
# Processing Record 49 of Set 6 | deputatskiy
# Processing Record 50 of Set 6 | nome
# Processing Record 1 of Set 7 | mhlume
# Processing Record 2 of Set 7 | ahipara
# Processing Record 3 of Set 7 | talnakh
# Processing Record 4 of Set 7 | pevek
# Processing Record 5 of Set 7 | coihueco
# Processing Record 6 of Set 7 | haines junction
# Processing Record 7 of Set 7 | rokytne
# Processing Record 8 of Set 7 | nizwa
# Processing Record 9 of Set 7 | egvekinot
# Processing Record 10 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 7 | nuuk
# Processing Record 12 of Set 7 | great falls
# Processing Record 13 of Set 7 | lufilufi
# Processing Record 14 of Set 7 | mount gambier
# Processing Record 15 of Set 7 | takoradi
# Processing Record 16 of Set 7 | lhokseumawe
# Processing Record 17 of Set 7 | limoges
# Processing Record 18 of Set 7 | itupiranga
# Processing Record 19 of Set 7 | puerto pinasco
# City not found. Skipping...
# Processing Record 20 of Set 7 | santa maria
# Processing Record 21 of Set 7 | vestmannaeyjar
# Processing Record 22 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 23 of Set 7 | cape canaveral
# Processing Record 24 of Set 7 | guerrero negro
# Processing Record 25 of Set 7 | sumenep
# Processing Record 26 of Set 7 | huilong
# Processing Record 27 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 28 of Set 7 | svetlogorsk
# Processing Record 29 of Set 7 | hambantota
# Processing Record 30 of Set 7 | ratnagiri
# Processing Record 31 of Set 7 | manthani
# Processing Record 32 of Set 7 | poum
# Processing Record 33 of Set 7 | zhigansk
# Processing Record 34 of Set 7 | hurricane
# Processing Record 35 of Set 7 | sao joao da barra
# Processing Record 36 of Set 7 | surab
# Processing Record 37 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 7 | quatre cocos
# Processing Record 39 of Set 7 | ormara
# Processing Record 40 of Set 7 | kumhari
# Processing Record 41 of Set 7 | bichura
# Processing Record 42 of Set 7 | gorom-gorom
# Processing Record 43 of Set 7 | bacolod
# Processing Record 44 of Set 7 | catuday
# Processing Record 45 of Set 7 | oudtshoorn
# Processing Record 46 of Set 7 | adrar
# Processing Record 47 of Set 7 | gamba
# Processing Record 48 of Set 7 | hofn
# Processing Record 49 of Set 7 | novyy urengoy
# Processing Record 50 of Set 7 | dalvik
# Processing Record 1 of Set 8 | baruun-urt
# Processing Record 2 of Set 8 | erenhot
# Processing Record 3 of Set 8 | san rafael
# Processing Record 4 of Set 8 | mehamn
# Processing Record 5 of Set 8 | maine-soroa
# Processing Record 6 of Set 8 | alofi
# Processing Record 7 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 8 | zhezkazgan
# Processing Record 9 of Set 8 | pisco
# Processing Record 10 of Set 8 | tasiilaq
# Processing Record 11 of Set 8 | broome
# Processing Record 12 of Set 8 | oak ridge
# Processing Record 13 of Set 8 | valparaiso
# Processing Record 14 of Set 8 | xining
# Processing Record 15 of Set 8 | codrington
# Processing Record 16 of Set 8 | ancud
# Processing Record 17 of Set 8 | carnarvon
# Processing Record 18 of Set 8 | forestville
# Processing Record 19 of Set 8 | muhos
# Processing Record 20 of Set 8 | tacoronte
# Processing Record 21 of Set 8 | yacuiba
# Processing Record 22 of Set 8 | sorong
# Processing Record 23 of Set 8 | vangaindrano
# Processing Record 24 of Set 8 | vanavara
# Processing Record 25 of Set 8 | berlevag
# Processing Record 26 of Set 8 | rurrenabaque
# Processing Record 27 of Set 8 | clarence town
# Processing Record 28 of Set 8 | wadi musa
# Processing Record 29 of Set 8 | gracac
# Processing Record 30 of Set 8 | olinda
# Processing Record 31 of Set 8 | ramhormoz
# Processing Record 32 of Set 8 | bud
# Processing Record 33 of Set 8 | cockburn town
# Processing Record 34 of Set 8 | rawson
# Processing Record 35 of Set 8 | kilinochchi
# Processing Record 36 of Set 8 | charleville
# Processing Record 37 of Set 8 | bilma
# Processing Record 38 of Set 8 | margate
# Processing Record 39 of Set 8 | altay
# Processing Record 40 of Set 8 | ugep
# Processing Record 41 of Set 8 | tongzi
# Processing Record 42 of Set 8 | kasempa
# Processing Record 43 of Set 8 | pitimbu
# Processing Record 44 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 8 | harper
# Processing Record 46 of Set 8 | paita
# Processing Record 47 of Set 8 | airai
# Processing Record 48 of Set 8 | razdolnoye
# Processing Record 49 of Set 8 | ulety
# Processing Record 50 of Set 8 | ippy
# Processing Record 1 of Set 9 | port blair
# Processing Record 2 of Set 9 | faya
# Processing Record 3 of Set 9 | qaqortoq
# Processing Record 4 of Set 9 | puerto escondido
# Processing Record 5 of Set 9 | muros
# Processing Record 6 of Set 9 | aksu
# Processing Record 7 of Set 9 | mbaiki
# Processing Record 8 of Set 9 | chkalovskoye
# Processing Record 9 of Set 9 | penzance
# Processing Record 10 of Set 9 | inhambane
# Processing Record 11 of Set 9 | cam ranh
# Processing Record 12 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 9 | awjilah
# Processing Record 14 of Set 9 | meulaboh
# Processing Record 15 of Set 9 | biak
# Processing Record 16 of Set 9 | rio grande
# Processing Record 17 of Set 9 | am timan
# Processing Record 18 of Set 9 | annau
# Processing Record 19 of Set 9 | ust-kuyga
# Processing Record 20 of Set 9 | nanga eboko
# Processing Record 21 of Set 9 | lucapa
# Processing Record 22 of Set 9 | iqaluit
# Processing Record 23 of Set 9 | narsaq
# Processing Record 24 of Set 9 | sioux lookout
# Processing Record 25 of Set 9 | goure
# Processing Record 26 of Set 9 | usinsk
# Processing Record 27 of Set 9 | north platte
# Processing Record 28 of Set 9 | eldikan
# City not found. Skipping...
# Processing Record 29 of Set 9 | el cobre
# Processing Record 30 of Set 9 | byron bay
# Processing Record 31 of Set 9 | conde
# Processing Record 32 of Set 9 | shanghai
# Processing Record 33 of Set 9 | juneau
# Processing Record 34 of Set 9 | henties bay
# Processing Record 35 of Set 9 | mount isa
# Processing Record 36 of Set 9 | vila franca do campo
# Processing Record 37 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 9 | campbell river
# Processing Record 39 of Set 9 | george town
# Processing Record 40 of Set 9 | anadyr
# Processing Record 41 of Set 9 | jinchang
# Processing Record 42 of Set 9 | kampong chhnang
# Processing Record 43 of Set 9 | katesh
# Processing Record 44 of Set 9 | parrita
# Processing Record 45 of Set 9 | san carlos
# Processing Record 46 of Set 9 | luan
# Processing Record 47 of Set 9 | kaseda
# Processing Record 48 of Set 9 | yarmouth
# Processing Record 49 of Set 9 | pacific grove
# Processing Record 50 of Set 9 | turinsk
# Processing Record 1 of Set 10 | port lincoln
# Processing Record 2 of Set 10 | lexington
# Processing Record 3 of Set 10 | lata
# Processing Record 4 of Set 10 | lamar
# Processing Record 5 of Set 10 | hudson bay
# Processing Record 6 of Set 10 | vila do maio
# Processing Record 7 of Set 10 | kyshtovka
# Processing Record 8 of Set 10 | plesetsk
# Processing Record 9 of Set 10 | souillac
# Processing Record 10 of Set 10 | acari
# Processing Record 11 of Set 10 | srivardhan
# Processing Record 12 of Set 10 | andenes
# Processing Record 13 of Set 10 | pangnirtung
# Processing Record 14 of Set 10 | huntsville
# Processing Record 15 of Set 10 | marck
# Processing Record 16 of Set 10 | srandakan
# Processing Record 17 of Set 10 | tabialan
# City not found. Skipping...
# Processing Record 18 of Set 10 | valdivia
# Processing Record 19 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 20 of Set 10 | oranjestad
# Processing Record 21 of Set 10 | richards bay
# Processing Record 22 of Set 10 | pak chong
# Processing Record 23 of Set 10 | ekpoma
# Processing Record 24 of Set 10 | balabac
# Processing Record 25 of Set 10 | nanakuli
# Processing Record 26 of Set 10 | santa marta
# Processing Record 27 of Set 10 | ryotsu
# Processing Record 28 of Set 10 | campestre
# Processing Record 29 of Set 10 | pauini
# Processing Record 30 of Set 10 | lakes entrance
# Processing Record 31 of Set 10 | boma
# Processing Record 32 of Set 10 | guicheng
# City not found. Skipping...
# Processing Record 33 of Set 10 | boueni
# Processing Record 34 of Set 10 | baturaja
# Processing Record 35 of Set 10 | arcachon
# Processing Record 36 of Set 10 | slobidka
# Processing Record 37 of Set 10 | kudahuvadhoo
# Processing Record 38 of Set 10 | melendugno
# Processing Record 39 of Set 10 | acarau
# Processing Record 40 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 41 of Set 10 | zaysan
# Processing Record 42 of Set 10 | visnes
# Processing Record 43 of Set 10 | college
# Processing Record 44 of Set 10 | nhulunbuy
# Processing Record 45 of Set 10 | olovyannaya
# Processing Record 46 of Set 10 | laibin
# Processing Record 47 of Set 10 | redmond
# Processing Record 48 of Set 10 | rocha
# Processing Record 49 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 10 | tongliao
# Processing Record 1 of Set 11 | yar-sale
# Processing Record 2 of Set 11 | calvinia
# Processing Record 3 of Set 11 | asau
# Processing Record 4 of Set 11 | port augusta
# Processing Record 5 of Set 11 | guayaramerin
# Processing Record 6 of Set 11 | novooleksiyivka
# Processing Record 7 of Set 11 | korla
# Processing Record 8 of Set 11 | naze
# Processing Record 9 of Set 11 | clyde river
# Processing Record 10 of Set 11 | klyuchi
# Processing Record 11 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 12 of Set 11 | zyryanka
# Processing Record 13 of Set 11 | nizhyn
# Processing Record 14 of Set 11 | mikuni
# Processing Record 15 of Set 11 | yulara
# Processing Record 16 of Set 11 | atikokan
# Processing Record 17 of Set 11 | roald
# Processing Record 18 of Set 11 | rockport
# Processing Record 19 of Set 11 | katra
# Processing Record 20 of Set 11 | conakry
# Processing Record 21 of Set 11 | ketchikan
# Processing Record 22 of Set 11 | kashi
# Processing Record 23 of Set 11 | songjianghe
# Processing Record 24 of Set 11 | kathmandu
# Processing Record 25 of Set 11 | porgera
# Processing Record 26 of Set 11 | paamiut
# Processing Record 27 of Set 11 | espinosa
# Processing Record 28 of Set 11 | portland
# Processing Record 29 of Set 11 | sekoma
# Processing Record 30 of Set 11 | sfantu gheorghe
# Processing Record 31 of Set 11 | bac lieu
# Processing Record 32 of Set 11 | ritchie
# Processing Record 33 of Set 11 | vreed en hoop
# City not found. Skipping...
# Processing Record 34 of Set 11 | katangli
# Processing Record 35 of Set 11 | santiago
# Processing Record 36 of Set 11 | darhan
# Processing Record 37 of Set 11 | poya
# Processing Record 38 of Set 11 | ostrovnoy
# Processing Record 39 of Set 11 | mabaruma
# Processing Record 40 of Set 11 | pinotepa nacional
# Processing Record 41 of Set 11 | belen
# Processing Record 42 of Set 11 | qui nhon
# Processing Record 43 of Set 11 | afua
# Processing Record 44 of Set 11 | san andres
# Processing Record 45 of Set 11 | reyes
# Processing Record 46 of Set 11 | semey
# Processing Record 47 of Set 11 | tiksi
# Processing Record 48 of Set 11 | kuliyapitiya
# Processing Record 49 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 11 | itaqui
# Processing Record 1 of Set 12 | kharp
# Processing Record 2 of Set 12 | sol-iletsk
# Processing Record 3 of Set 12 | oskemen
# Processing Record 4 of Set 12 | chodavaram
# Processing Record 5 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 6 of Set 12 | kidal
# Processing Record 7 of Set 12 | hare bay
# Processing Record 8 of Set 12 | vila velha
# Processing Record 9 of Set 12 | kedrovyy
# Processing Record 10 of Set 12 | port shepstone
# Processing Record 11 of Set 12 | fevik
# Processing Record 12 of Set 12 | virginia beach
# Processing Record 13 of Set 12 | kirakira
# Processing Record 14 of Set 12 | wladyslawowo
# Processing Record 15 of Set 12 | gimbi
# Processing Record 16 of Set 12 | ternat
# Processing Record 17 of Set 12 | shakiso
# Processing Record 18 of Set 12 | venado tuerto
# Processing Record 19 of Set 12 | kresttsy
# Processing Record 20 of Set 12 | matamoros
# Processing Record 21 of Set 12 | fallon
# Processing Record 22 of Set 12 | sompeta
# Processing Record 23 of Set 12 | yeppoon
# Processing Record 24 of Set 12 | lompoc
# Processing Record 25 of Set 12 | kungurtug
# Processing Record 26 of Set 12 | mosquera
# Processing Record 27 of Set 12 | hami
# Processing Record 28 of Set 12 | gigmoto
# Processing Record 29 of Set 12 | bowen
# Processing Record 30 of Set 12 | potosi
# Processing Record 31 of Set 12 | murray bridge
# Processing Record 32 of Set 12 | wad madani
# Processing Record 33 of Set 12 | otterup
# Processing Record 34 of Set 12 | batagay-alyta
# Processing Record 35 of Set 12 | kattivakkam
# Processing Record 36 of Set 12 | price
# Processing Record 37 of Set 12 | sinnamary
# Processing Record 38 of Set 12 | hoquiam
# Processing Record 39 of Set 12 | buraydah
# Processing Record 40 of Set 12 | paralimni
# Processing Record 41 of Set 12 | sokoni
# Processing Record 42 of Set 12 | sofiysk
# City not found. Skipping...
# Processing Record 43 of Set 12 | shache
# Processing Record 44 of Set 12 | yanchukan
# City not found. Skipping...
# Processing Record 45 of Set 12 | qinnan
# Processing Record 46 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 47 of Set 12 | novopokrovka
# Processing Record 48 of Set 12 | las tunas
# Processing Record 49 of Set 12 | tianpeng
# Processing Record 50 of Set 12 | natal
# Processing Record 1 of Set 13 | kuryk
# Processing Record 2 of Set 13 | coahuayana
# Processing Record 3 of Set 13 | ramanuj ganj
# Processing Record 4 of Set 13 | nyrob
# Processing Record 5 of Set 13 | ust-ishim
# Processing Record 6 of Set 13 | virar
# Processing Record 7 of Set 13 | makakilo city
# Processing Record 8 of Set 13 | genhe
# Processing Record 9 of Set 13 | renqiu
# Processing Record 10 of Set 13 | isangel
# Processing Record 11 of Set 13 | alanya
# Processing Record 12 of Set 13 | jalu
# Processing Record 13 of Set 13 | tuatapere
# Processing Record 14 of Set 13 | carlsbad
# Processing Record 15 of Set 13 | wattegama
# Processing Record 16 of Set 13 | santa isabel do rio negro
# Processing Record 17 of Set 13 | shimoda
# Processing Record 18 of Set 13 | dunedin
# Processing Record 19 of Set 13 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 13 | aktash
# Processing Record 21 of Set 13 | soe
# Processing Record 22 of Set 13 | general pico
# Processing Record 23 of Set 13 | ginir
# Processing Record 24 of Set 13 | kavaratti
# Processing Record 25 of Set 13 | spirit river
# Processing Record 26 of Set 13 | beeville
# Processing Record 27 of Set 13 | colares
# Processing Record 28 of Set 13 | yungay
# Processing Record 29 of Set 13 | kaeo
# Processing Record 30 of Set 13 | okhotsk
# Processing Record 31 of Set 13 | jaguey grande
# Processing Record 32 of Set 13 | falmouth
# Processing Record 33 of Set 13 | mayumba
# Processing Record 34 of Set 13 | talawdi
# City not found. Skipping...
# Processing Record 35 of Set 13 | alyangula
# Processing Record 36 of Set 13 | kholtoson
# Processing Record 37 of Set 13 | letlhakane
# Processing Record 38 of Set 13 | manggar
# Processing Record 39 of Set 13 | patacamaya
# Processing Record 40 of Set 13 | santa cruz
# Processing Record 41 of Set 13 | jibuti
# Processing Record 42 of Set 13 | awbari
# Processing Record 43 of Set 13 | trincomalee
# Processing Record 44 of Set 13 | picton
# Processing Record 45 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 13 | baykit
# Processing Record 47 of Set 13 | birin
# Processing Record 48 of Set 13 | zheleznodorozhnyy
# Processing Record 49 of Set 13 | olkhovka
# Processing Record 50 of Set 13 | ziro
# Processing Record 1 of Set 14 | sur
# Processing Record 2 of Set 14 | tocopilla
# Processing Record 3 of Set 14 | houma
# Processing Record 4 of Set 14 | lipari
# Processing Record 5 of Set 14 | saurimo
# Processing Record 6 of Set 14 | areado
# Processing Record 7 of Set 14 | hamilton
# Processing Record 8 of Set 14 | stornoway
# Processing Record 9 of Set 14 | voskresenskoye
# Processing Record 10 of Set 14 | riverton
# Processing Record 11 of Set 14 | portlethen
# Processing Record 12 of Set 14 | hearst
# Processing Record 13 of Set 14 | phangnga
# Processing Record 14 of Set 14 | omboue
# Processing Record 15 of Set 14 | todos santos
# Processing Record 16 of Set 14 | surt
# Processing Record 17 of Set 14 | tigzirt
# Processing Record 18 of Set 14 | shar
# Processing Record 19 of Set 14 | raga
# Processing Record 20 of Set 14 | aktyubinskiy
# Processing Record 21 of Set 14 | port hardy
# Processing Record 22 of Set 14 | del rio
# Processing Record 23 of Set 14 | evensk
# Processing Record 24 of Set 14 | jedburgh
# Processing Record 25 of Set 14 | zhigalovo
# Processing Record 26 of Set 14 | west wendover
# Processing Record 27 of Set 14 | fethiye
# Processing Record 28 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 29 of Set 14 | davila
# Processing Record 30 of Set 14 | mpanda
# Processing Record 31 of Set 14 | elko
# Processing Record 32 of Set 14 | najran
# Processing Record 33 of Set 14 | hidalgo
# Processing Record 34 of Set 14 | kondinskoye
# Processing Record 35 of Set 14 | jacareacanga
# Processing Record 36 of Set 14 | businga
# Processing Record 37 of Set 14 | novoselitskoye
# Processing Record 38 of Set 14 | bereda
# Processing Record 39 of Set 14 | ibra
# Processing Record 40 of Set 14 | beloha
# Processing Record 41 of Set 14 | kaduy
# Processing Record 42 of Set 14 | north bend
# Processing Record 43 of Set 14 | lac du bonnet
# Processing Record 44 of Set 14 | vaitape
# Processing Record 45 of Set 14 | lichinga
# Processing Record 46 of Set 14 | rio gallegos
# Processing Record 47 of Set 14 | lincoln
# Processing Record 48 of Set 14 | sembakung
# Processing Record 49 of Set 14 | saint-francois
# Processing Record 50 of Set 14 | bandar maharani
# City not found. Skipping...
# Processing Record 1 of Set 15 | tromso
# Processing Record 2 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 3 of Set 15 | kailua
# Processing Record 4 of Set 15 | ban nahin
# Processing Record 5 of Set 15 | nicoya
# Processing Record 6 of Set 15 | walvis bay
# Processing Record 7 of Set 15 | caranavi
# Processing Record 8 of Set 15 | el tigre
# Processing Record 9 of Set 15 | geraldton
# Processing Record 10 of Set 15 | sechura
# Processing Record 11 of Set 15 | leshukonskoye
# Processing Record 12 of Set 15 | oyama
# Processing Record 13 of Set 15 | saint pete beach
# Processing Record 14 of Set 15 | chlumec
# Processing Record 15 of Set 15 | pyshma
# Processing Record 16 of Set 15 | esperanza
# Processing Record 17 of Set 15 | goderich
# Processing Record 18 of Set 15 | lima
# Processing Record 19 of Set 15 | dilla
# Processing Record 20 of Set 15 | batsfjord
# Processing Record 21 of Set 15 | taree
# Processing Record 22 of Set 15 | rio cuarto
# Processing Record 23 of Set 15 | zhovtneve
# Processing Record 24 of Set 15 | trairi
# Processing Record 25 of Set 15 | manono
# Processing Record 26 of Set 15 | lorengau
# Processing Record 27 of Set 15 | poli
# Processing Record 28 of Set 15 | kenai
# Processing Record 29 of Set 15 | kalabo
# Processing Record 30 of Set 15 | benguela
# Processing Record 31 of Set 15 | mokokchung
# Processing Record 32 of Set 15 | kiunga
# Processing Record 33 of Set 15 | novosheshminsk
# Processing Record 34 of Set 15 | wanning
# Processing Record 35 of Set 15 | sao jose da coroa grande
# Processing Record 36 of Set 15 | aksha
# Processing Record 37 of Set 15 | zachary
# Processing Record 38 of Set 15 | kismayo
# Processing Record 39 of Set 15 | onokhoy
# Processing Record 40 of Set 15 | simao
# Processing Record 41 of Set 15 | marsciano
# Processing Record 42 of Set 15 | lenger
# Processing Record 43 of Set 15 | eyl
# Processing Record 44 of Set 15 | fort nelson
# Processing Record 45 of Set 15 | neiafu
# Processing Record 46 of Set 15 | maragogi
# Processing Record 47 of Set 15 | monrovia
# Processing Record 48 of Set 15 | vavozh
# Processing Record 49 of Set 15 | batagay
# Processing Record 50 of Set 15 | lishu
# Processing Record 1 of Set 16 | beian
# Processing Record 2 of Set 16 | coquimbo
# Processing Record 3 of Set 16 | kiama
# Processing Record 4 of Set 16 | san carlos de bariloche
# Processing Record 5 of Set 16 | blagoyevo
# Processing Record 6 of Set 16 | tres arroyos
# Processing Record 7 of Set 16 | aksarka
# Processing Record 8 of Set 16 | sao felix do xingu
# Processing Record 9 of Set 16 | morondava
# Processing Record 10 of Set 16 | floro
# Processing Record 11 of Set 16 | jieshi
# Processing Record 12 of Set 16 | lasa
# Processing Record 13 of Set 16 | milingimbi
# City not found. Skipping...
# Processing Record 14 of Set 16 | donzdorf
# Processing Record 15 of Set 16 | milkovo
# Processing Record 16 of Set 16 | fevralsk
# City not found. Skipping...
# Processing Record 17 of Set 16 | tautira
# Processing Record 18 of Set 16 | temuco
# Processing Record 19 of Set 16 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 16 | karkaralinsk
# City not found. Skipping...
# Processing Record 21 of Set 16 | kukshi
# Processing Record 22 of Set 16 | vitim
# Processing Record 23 of Set 16 | kedougou
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        albany  42.6001  -73.9662     35.62        52          42
# 1  ponta do sol  32.6667  -17.1000     67.01        72          48
# 2  punta arenas -53.1500  -70.9167     51.12        50          57
# 3   kloulklubed   7.0419  134.2556     78.80        82         100
# 4       qaanaaq  77.4840  -69.3632    -18.27        73         100
# 5        dikson  73.5069   80.5464      3.94        93         100
# 6         bluff -46.6000  168.3333     73.80        71         100
# 7     busselton -33.6500  115.3333     61.05        67          21
# 8       bubaque  11.2833  -15.8333     78.64        79           4
# 9     caravelas -17.7125  -39.2481     80.01        82          63
#
#    Wind Speed Country Current Description
# 0        1.99      US    scattered clouds
# 1       11.81      PT    scattered clouds
# 2       26.22      CL       broken clouds
# 3       16.91      PW       moderate rain
# 4       11.88      GL     overcast clouds
# 5       18.30      RU     overcast clouds
# 6       13.18      NZ     overcast clouds
# 7       18.28      AU          few clouds
# 8       14.81      GW           clear sky
# 9        8.16      BR       broken clouds

# %%
city_data_df["Lat"]=city_data_df["Lat"].map("{:,.2f}".format)
city_data_df["Lng"]=city_data_df["Lng"].map("{:,.2f}".format)
city_data_df.head(10)
# Out:
#            City     Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        albany   42.60  -73.97     35.62        52          42        1.99
# 1  ponta do sol   32.67  -17.10     67.01        72          48       11.81
# 2  punta arenas  -53.15  -70.92     51.12        50          57       26.22
# 3   kloulklubed    7.04  134.26     78.80        82         100       16.91
# 4       qaanaaq   77.48  -69.36    -18.27        73         100       11.88
# 5        dikson   73.51   80.55      3.94        93         100       18.30
# 6         bluff  -46.60  168.33     73.80        71         100       13.18
# 7     busselton  -33.65  115.33     61.05        67          21       18.28
# 8       bubaque   11.28  -15.83     78.64        79           4       14.81
# 9     caravelas  -17.71  -39.25     80.01        82          63        8.16
#
#   Country Current Description
# 0      US    scattered clouds
# 1      PT    scattered clouds
# 2      CL       broken clouds
# 3      PW       moderate rain
# 4      GL     overcast clouds
# 5      RU     overcast clouds
# 6      NZ     overcast clouds
# 7      AU          few clouds
# 8      GW           clear sky
# 9      BR       broken clouds

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#              City Country     Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0          albany      US   42.60   -73.97     35.62        52          42
# 1    ponta do sol      PT   32.67   -17.10     67.01        72          48
# 2    punta arenas      CL  -53.15   -70.92     51.12        50          57
# 3     kloulklubed      PW    7.04   134.26     78.80        82         100
# 4         qaanaaq      GL   77.48   -69.36    -18.27        73         100
# ..            ...     ...     ...      ...       ...       ...         ...
# 709       tautira      PF  -17.73  -149.15     86.02        77          25
# 710        temuco      CL  -38.73   -72.60     78.57        34           1
# 711        kukshi      IN   22.20    74.75     67.39        48           2
# 712         vitim      RU   59.45   112.56     -4.68        99         100
# 713      kedougou      SN   12.56   -12.17     84.29        13           6
#
#      Wind Speed Current Description
# 0          1.99    scattered clouds
# 1         11.81    scattered clouds
# 2         26.22       broken clouds
# 3         16.91       moderate rain
# 4         11.88     overcast clouds
# ..          ...                 ...
# 709       20.80          light rain
# 710       10.89           clear sky
# 711        2.15           clear sky
# 712        3.87     overcast clouds
# 713        4.85           clear sky
#
# [714 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
